# %% [markdown]
# _This notebook is part of the material for the [ML Tutorials](https://github.com/NNPDF/como-2025) session._
#
# # Jet Classification with CNN

# %% [markdown]
# In this tutorial we are going to solve a classification problem.
#
# This tutorial is partially based on [this tutorial](https://github.com/bmdillon/dlpp-tutorials/blob/main/tutorial-5-jet-classification-with-cnns.ipynb) and [these notes](https://arxiv.org/pdf/2211.01421.pdf) The data has been curated from the top tagging data from [2107.00656](https://arxiv.org/pdf/2107.00656.pdf).
#
# You should already have this data prepared during the installation phase (tutorial 1!)
#
# Note that in the original tutorial the files used were 1.5 GB (and around 20gb uncompressed) we have made them much smaller to facilitate running the tutorial. Furthermore, the original tutorial used `pytorch`, instead in this one we are using `tensorflow` to be consistent with the other tutorials (and the `nnpdf` codebase) however all concepts are equally applicable.

# %% [markdown]
# #### Description of the dataset
#
# Top tagging dataset. Printout from `pd4ml.TopTagging.print_description()`.
#
#     Description:
#     14 TeV, hadronic tops for signal, QCD djets background, Delphes ATLAS detector card with Pythia. No MPI/pile-up included
#     Particle-flow entries (produced by Delphes E-flow) have been clustered into anti-kT 0.8 jets in the pT range [550,650].
#     All top jets are matched to a parton-level top within ∆R = 0.8, and to all top decay partons within 0.8. Also,|eta|_jet < 2 has been required.
#
#     Ref:
#     Deep-learned Top Tagging with a Lorentz Layer by A Butter, G Kasieczka, T and M Russell (arXiv: 1707.08966)
#
#     Dataset shape:
#     ~2M events have been stored divided between training (~1.6M) and test (~400k)) and the shape of the dataset is (# of events, 200, 4).
#     The feature represent the leading 200 jet constituent four-momenta, with zero-padding for jets that have less than 200.
#     Constituents are sorted by pT, with the highest pT one first.
#
#     The second dataset that is included is just a flag "ttv" to identify what the event was before the reshaping operated by us. Here a legenda:
#         0 = training event;
#         1 = test event;
#         2 = validation event;
#
#     Note that in the current splitting of the dataset, training and validation events have been merged together as a unique training dataset. So for most intents and purposes one should just train the model on the first dataset and omit the second 'ttv' dataset altogether.
#
#     The set label are 0 for QCD and 1 for top.
#
# The 4-momenta is written as (E, px, py, pz)
#
# Note:
# It is possible to repeat this exercise by utilizing the bigger version of the dataset to really se the "power of the Big Data". For that please follow the instructions in the official [repository](https://github.com/erum-data-idt/pd4ml/blob/main/examples/1_top_plots.ipynb) of `pd4ml`. In the tutorial below we are using a smaller version of it with ~100k events instead of ~2M. we are going to use a small version of it. In our case, instead of having ~2M events we only have ~100k.

# %% [markdown]
# # Start of the tutorial
#
# Let's begin by loading the top tagging data into the notebook

# %%
# First let's import everything we will need and set the folder where you put all your data!
from pathlib import Path

import numpy as np
from matplotlib import pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow import keras

tf.keras.backend.clear_session()

plt.rcParams["figure.figsize"] = (10, 10)
data_folder = Path("data")
if not data_folder.exists():
    print("Warning! The data folder does not exist!")

# %%
# Load the data
dataset = np.load(data_folder / "toptagging.npz")
raw_input_data = dataset["x"] # (nevents, nconstituents, 4momenta)
labels = dataset["y"] # 0 for QCD, 1 for top

# Cut down the number of events, setting this to `False` could affect your computer memory!
if True:
    cutdown = int(4e4)
    raw_input_data = raw_input_data[:cutdown]
    labels = labels[:cutdown]

full_ndata = len(labels)
training_ndata = int(full_ndata/2)
# Take only part of the data for training, the rest will be "new unseen data"
raw_test_data = raw_input_data[training_ndata:]
test_labels = labels[training_ndata:]
# We will only go back to these test_arrays at the end
# from now on, we only see training data
ndata = training_ndata
raw_input_data = raw_input_data[:ndata]
labels = labels[:ndata]
print(f"We have loaded {ndata} events (and hidden {full_ndata-ndata} away to test our results later!)")
# Out:
# We have loaded 20000 events (and hidden 20000 away to test our results later!)

# %% [markdown]
# ## Preprocessing jet images
#
# We are going to treat this problem as an image classification problem.
# To that end we are going to transform every jet event into an image.
#
# We use the 4-momenta to compute $(p_{T}, \eta, \phi)$ (transverse momentum, pseudorapidity and azimuthal angle) for every constituent of the jet and then we use that information to cast them into a grid of pixels
#
# The following cell contains auxiliary functions modified from [this notebook](https://github.com/bmdillon/dlpp-tutorials/blob/main/tutorial-5-jet-classification-with-cnns.ipynb)

# %%
epsilon = 1e-10
warning_shift_eta = 0
warning_shift_phi = 0

# Set the grid of 180 x 180 pixels
XPIXELS = np.arange(-2.6, 2.6, 0.029)
YPIXELS = np.arange(-np.pi, np.pi, 0.035)
NX = len(XPIXELS)
NY = len(YPIXELS)


def comp_eta(pt, pz):
    """Given the transverse and longitudinal momentum, return the pseudorapidity of the particle
    The input arrays are expected to be (n_events, n_constituents)
    """
    # Remove values that might introduce instabilities
    safe_vals = (np.abs(pt) > epsilon) & (np.abs(pz) > epsilon)
    theta = np.arctan(pt[safe_vals] / pz[safe_vals])
    theta[theta < 0] += np.pi
    etas = np.zeros_like(pt)
    etas[safe_vals] = np.log(np.tan(theta / 2))
    # Recover the very small not-zero ones
    etas[np.abs(pt) <= epsilon] = epsilon
    return etas


# Calculate the azimuthal angle of pixel entries
def comp_phi(px, py):
    """Compute the azimuthal angle in rad, np.arctan(0,0)=0 -> zero constituents set to -np.pi
    The input arrays are expected to be (n_events, n_constituents)
    """
    phis = np.arctan2(py, px)
    phis[phis < 0] += 2 * np.pi
    phis[phis > 2 * np.pi] -= 2 * np.pi
    phis = phis - np.pi
    return phis


def dot4m(p1s, p2s):
    """Compute the dot product between two arrays of 4-momenta, input_shape: (nevents, 4)"""
    vec = np.sum(p1s[:, 1:] * p2s[:, 1:], axis=-1)
    return p1s[:, 0] * p2s[:, 0] - vec


def invariant_mass(jets):
    """Compute the invariant mass of the jets. The input array is expected to be (n_events, n_constituent, 4)"""
    sum_momenta = np.sum(jets, axis=1)
    m2 = dot4m(sum_momenta, sum_momenta)
    return np.sqrt(np.maximum(0.0, m2))


def preprocessing_jet(x, y, w, warning_threshold=0.7, rotate=True, flip=True):
    """Preprocessing of the jets eta and phi (x and y) in preparation for the conversion into images.
    The weights (w) is the pt.
    The input of this function is 1dimensional arrays of n_constituents.
    It returns x and y shifted and rotated so that they are ripe to become the coordinate in an image.

    The image is rotated so that the principal axis
    is vertical.
    Method for calculating principal axis (similar to tensor of inertia):
    https://en.wikipedia.org/wiki/Image_moment

    At the end of the function the image is flipped so that most weights
    lay in the (x<0, y>0)-plane
    """
    # Compute the centroid and shift x/y
    norm = w.sum(axis=-1)
    x_centroid = (x * w).sum(axis=-1) / norm
    y_centroid = (y * w).sum(axis=-1) / norm
    x = x - x_centroid[:, None]
    y = y - y_centroid[:, None]

    # The original notebook talks about possible problems
    # with the shifting, let's keep track of that just in case
    warning_shift_eta = np.count_nonzero(np.abs(x[:, 0]) > warning_threshold)
    warning_shift_phi = np.count_nonzero(np.abs(y[:, 0]) > warning_threshold)
    if warning_shift_eta != 0 or warning_shift_phi != 0:
        print(f"Problems in the shifts! {warning_shift_eta=}, {warning_shift_phi=}")

    if rotate:
        ### Compute rotation
        # Covariant matrix, eigenvectors corr. to principal axis
        u11 = (x * y * w).sum(axis=-1) / norm
        u20 = (x**2 * w).sum(axis=-1) / norm
        u02 = (y**2 * w).sum(axis=-1) / norm
        cov = np.array([[u20, u11], [u11, u02]]).T  # (nevents, 2, 2)

        evals, evecs = np.linalg.eig(cov)

        # Sort the eigenvalues
        sort_indices = np.argsort(evals, axis=-1)
        ev_1 = []
        ev_2 = []
        for ev, ss in zip(evecs, sort_indices):
            ev_1.append(ev[..., ss[1]])  # Eigenvector with largest eigenvalue
            ev_2.append(ev[..., ss[0]])
        ev_1 = np.array(ev_1)
        ev_2 = np.array(ev_2)

        # Theta to x_asix, arctan2 gives correct angle
        theta = np.arctan2(ev_1[:, 0], ev_1[:, 1])

        # Rotation, so that princple axis is vertical
        # anti-clockwise rotation matrix
        rotation = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]])

        stacked_xy = np.stack([x, y])
        transformed_mat = np.einsum("ijn, inc-> njc", rotation, stacked_xy)
        x_rot = transformed_mat[:, 0]
        y_rot = transformed_mat[:, 1]
    else:
        x_rot = x
        y_rot = y

    if flip:
        wxp = np.sum(x_rot > 0, axis=-1)
        wxm = np.sum(x_rot < 0, axis=-1)
        wyp = np.sum(x_rot > 0, axis=-1)
        wym = np.sum(x_rot < 0, axis=-1)

        # We want the X (eta) in the negative quadrant
        xflip = np.where(wxm > wxp, 1.0, -1.0)
        # And the y (phi) in the positive
        yflip = np.where(wym < wyp, 1.0, -1.0)

        x_rot *= xflip[:, None]
        y_rot *= yflip[:, None]

    return x_rot, y_rot


def pixelize(x, y, w):
    """Make the (x, y, w) arrays into pixels. To that end,
    discretize x and y by rounding (eta=1.3 -> pixel 1, eta=1.6->pixel2)

    The output is nevent images of (NX, NY) pixels
    """
    nevents = x.shape[0]
    nconsti = x.shape[1]
    z_out = np.zeros((nevents, NX, NY))
    ## Get the index in the pixel grid for x and y
    x_tmp = x[:, None, :] - XPIXELS[None, :, None]
    y_tmp = y[:, None, :] - YPIXELS[None, :, None]
    x_coord = np.argmin(np.abs(x_tmp), axis=1)
    y_coord = np.argmin(np.abs(y_tmp), axis=1)
    # Select only the constituents that are _inside_ the grid of pixels
    xmin = XPIXELS[0]
    xmax = XPIXELS[-1]
    ymin = YPIXELS[0]
    ymax = YPIXELS[-1]
    in_grid = (xmin <= x) & (x <= xmax) & (ymin <= y) & (y <= ymax)
    n_coord = np.repeat(np.arange(nevents)[:, None], nconsti, axis=1)
    z_out[n_coord[in_grid], x_coord[in_grid], y_coord[in_grid]] = w[in_grid]
    return z_out


# function to convert the jet to an image
def constituents_to_image(
    jets, n_constituents=50, rotate=True, flip=True, zoom_in=True, zoom_pixels=40
):
    """Transform the array of constituents of the jet into an image
    The input of this function is an array of (nevents, nconstituents, 4)
    The output is shape (nevents, NX*NY)
    where NX and NY is the number of pixels in the X and Y axis
    note that if the zoom is active they will be equal to zoom_pixels

    Parameters
    ----------
        jets: array of events (nevents, nconstituents, 4)
        n_constituents: int
            How many of the constituents should be used (default = 50)
        rotate: bool
            rotate the image so that the principal axis is in vertical
        flip: bool
            flip image so that they are in the (x<0, y>0)-plane
        zoom_in: bool
            zoom in to a smaller number of pixels around the center (default=true)
        zoom_pixels: int
            how many pixels around the center we actually want (default=40)
    """
    if n_constituents >= (nc := jets.shape[1]):
        raise ValueError(f"You asked to use {n_constituents} but only {nc} are available")

    jets = jets[:, :n_constituents, :]

    pxs = jets[:, :, 1]
    pys = jets[:, :, 2]
    pzs = jets[:, :, 3]

    print("Calculating pT...")
    weights = pts = np.sqrt(pxs**2 + pys**2)

    print("Calculating pseudorapidity... ")
    etas = comp_eta(pts, pzs)

    print("Calculating azimuthal angle")
    phis = comp_phi(pxs, pys)
    # This weird preshifting of phi is done here
    # because of the shifting done in the preprocessing
    phis = (phis.T - phis[:, 0]).T
    phis[phis < -np.pi] += 2 * np.pi
    phis[phis > np.pi] -= 2 * np.pi

    print("Preprocessing jets")
    x, y = preprocessing_jet(etas, phis, weights, rotate=rotate, flip=flip)

    print("Pixelixing")
    z_full = pixelize(x, y, weights)

    if not zoom_in:
        return z_full.reshape(-1, NX * NY)

    print(f"Cropping images to a {zoom_pixels}x{zoom_pixels} grid")

    # zoom in around the center (and normalize)
    # Prepare the crop-coordinates
    xcrop_m = int(NX / 2 - zoom_pixels / 2)
    xcrop_p = int(NX / 2 + zoom_pixels / 2)
    ycrop_m = int(NY / 2 - zoom_pixels / 2)
    ycrop_p = int(NY / 2 + zoom_pixels / 2)

    z_new = z_full[:, xcrop_m:xcrop_p, ycrop_m:ycrop_p]

    # Now normalize
    z_norm = np.sum(z_new, axis=(1, 2))[:, None, None]
    z_new /= z_norm + 1e-10
    return z_new.reshape(-1, zoom_pixels**2)

# %%
pixels = 40
print(f" Preparing the training set")
z_train = constituents_to_image(raw_input_data, zoom_pixels=pixels)
print("\n> Preparing the test set")
z_test = constituents_to_image(raw_test_data, zoom_pixels=pixels)
# Out:
#  Preparing the training set
# Calculating pT...
# Calculating pseudorapidity...
# Calculating azimuthal angle
# Preprocessing jets
# Pixelixing
# Cropping images to a 40x40 grid
#
# > Preparing the test set
# Calculating pT...
# Calculating pseudorapidity...
# Calculating azimuthal angle
# Preprocessing jets
# Pixelixing
# Cropping images to a 40x40 grid

# %% [markdown]
# ## Data visualization
#
# Since we have images, before feeding them to the Machine Learning algorithms, let's play a bit with them to see how they look

# %%
# Let's plot a few of these images we just constructed!
for i in range(4):
    plt.subplot(2, 2, i + 1)
    n = np.random.randint(ndata) # Take them randomly
    # Note that we need to reshape the array into a pixelsXpixels grid
    jet = z_train[n].reshape((pixels, pixels))
    if labels[n] == 1:
        label = "Signal"
    else:
        label = "Background"
    plt.title(f"Jet {n} ({label})")
    plt.imshow(jet, cmap="gist_heat_r")

    plt.xlabel(r"$\eta$")
    plt.ylabel(r"$\phi$")

    ticks = np.linspace(0, 40, 5)
    yti = [r"$\pi$", r"$\pi/2$", 0, r"$-\pi/2$", r"$-\pi$"]
    xti = [f"{i:.2}" for i in np.linspace(-4, 4, 5)]
    plt.yticks(ticks, yti)
    plt.xticks(ticks, xti)

# %% [markdown]
# We can get a "human learning" idea of what will be signal and what will be background by having a look at the average colormaps:

# %%
signal = z_train[ labels==1 ]
background = z_train[ labels==0 ]

# %%
mean_signal = signal.mean(axis=0).reshape(pixels, pixels)
mean_bkg = background.mean(axis=0).reshape(pixels, pixels)

plt.subplot(1, 2, 1)
plt.title("Signal")
plt.imshow(mean_signal, cmap="gist_heat_r")
plt.xlabel(r"$\eta$")
plt.ylabel(r"$\phi$")

ticks = np.linspace(0, 40, 5)
yti = [r"$\pi$", r"$\pi/2$", 0, r"$-\pi/2$", r"$-\pi$"]
xti = [f"{i:.2}" for i in np.linspace(-4, 4, 5)]
plt.yticks(ticks, yti)
plt.xticks(ticks, xti)

plt.subplot(1, 2, 2)
plt.title("Background")
plt.imshow(mean_bkg, cmap="gist_heat_r")
plt.xlabel(r"$\eta$")
plt.ylabel(r"$\phi$")

ticks = np.linspace(0, 40, 5)
yti = [r"$\pi$", r"$\pi/2$", 0, r"$-\pi/2$", r"$-\pi$"]
xti = [f"{i:.2}" for i in np.linspace(-4, 4, 5)]
plt.yticks(ticks, yti)
plt.xticks(ticks, xti);

# %% [markdown]
# ## Building the CNN
#
# We first start by building a simple Convolutional Neural Network using TensorFlow's `sequential` model

# %%
# Put the values in a format suitable for tensorflow input and compute some parameters
# The tensorflow NN assumes color channels, in our case this (1)
in_data = z_train.reshape(-1, pixels, pixels, 1)
test_data = z_test.reshape(-1, pixels, pixels, 1)
# and set some parameters
epochs = 200
batch_size = 1000
trvl = 0.2 # % of data that go into validation

# %%
cnn_model = Sequential(name="CNN")
cnn_model.add(  keras.Input(shape=in_data[0].shape))

# Convolution and Max-Pooling
cnn_model.add(  keras.layers.Conv2D(4, (5,5), activation="relu", padding="same")  )
cnn_model.add(  keras.layers.MaxPooling2D((2,2))  )
cnn_model.add(  keras.layers.Conv2D(1, (5,5), activation="relu", padding="same")  )
cnn_model.add(  keras.layers.MaxPooling2D((2,2))  )

# Flatten and fully connected
cnn_model.add(  keras.layers.Flatten() )
cnn_model.add(  keras.layers.Dense(50, activation="relu")  )

# Output layer, units = 2 and "softmax" would also work!
cnn_model.add(  keras.layers.Dense(1, activation="sigmoid")  )
cnn_model.summary()
# Out:
# Model: "CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 40, 40, 4)      │           104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 20, 20, 4)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 20, 20, 1)      │           101 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,306 (20.73 KB)
#  Trainable params: 5,306 (20.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
opt = keras.optimizers.Adam(learning_rate=0.001)
cnn_model.compile(
    optimizer=opt,
    loss=keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy']
)

# %%
# Let's prepare a checkpoint so that we have the best weights of every epoch
# this will allow us to play some interesting games
# Some more information about this https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint
# Let's save the per-epoch weight:
output_path = "output_jets/output_path_epoch_{epoch:03d}.weights.h5"
Path(output_path).parent.mkdir(exist_ok=True)

model_checkpoint = keras.callbacks.ModelCheckpoint(output_path,
                                                   save_best_only=True, # only save the best model
                                                   save_weights_only = True,
                                                   save_freq="epoch")

# %%
history = cnn_model.fit(
    in_data,
    labels,
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[model_checkpoint],
    validation_split=trvl,
    verbose=1 # change to 0 to disable output during training
)
# Out:
# Epoch 1/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.6102 - loss: 0.6915 - val_accuracy: 0.8090 - val_loss: 0.6805
# Epoch 2/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8062 - loss: 0.6747 - val_accuracy: 0.7880 - val_loss: 0.6516
# Epoch 3/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8080 - loss: 0.6396 - val_accuracy: 0.8060 - val_loss: 0.5973
# Epoch 4/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8103 - loss: 0.5794 - val_accuracy: 0.8265 - val_loss: 0.5196
# Epoch 5/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8209 - loss: 0.4998 - val_accuracy: 0.8250 - val_loss: 0.4489
# Epoch 6/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8174 - loss: 0.4457 - val_accuracy: 0.8160 - val_loss: 0.4246
# Epoch 7/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8222 - loss: 0.4199 - val_accuracy: 0.8288 - val_loss: 0.4146
# Epoch 8/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8214 - loss: 0.4180 - val_accuracy: 0.8320 - val_loss: 0.4093
# Epoch 9/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8329 - loss: 0.4019 - val_accuracy: 0.8263 - val_loss: 0.4064
# Epoch 10/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8289 - loss: 0.4050 - val_accuracy: 0.8338 - val_loss: 0.4032
# Epoch 11/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8342 - loss: 0.3996 - val_accuracy: 0.8355 - val_loss: 0.3950
# Epoch 12/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8354 - loss: 0.3928 - val_accuracy: 0.8357 - val_loss: 0.3910
# Epoch 13/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8310 - loss: 0.3917 - val_accuracy: 0.8357 - val_loss: 0.3860
# Epoch 14/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8381 - loss: 0.3842 - val_accuracy: 0.8395 - val_loss: 0.3824
# Epoch 15/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8350 - loss: 0.3841 - val_accuracy: 0.8393 - val_loss: 0.3799
# Epoch 16/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8340 - loss: 0.3837 - val_accuracy: 0.8418 - val_loss: 0.3765
# Epoch 17/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8371 - loss: 0.3787 - val_accuracy: 0.8435 - val_loss: 0.3730
# Epoch 18/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8422 - loss: 0.3728 - val_accuracy: 0.8425 - val_loss: 0.3682
# Epoch 19/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8407 - loss: 0.3699 - val_accuracy: 0.8465 - val_loss: 0.3665
# Epoch 20/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8389 - loss: 0.3711 - val_accuracy: 0.8482 - val_loss: 0.3628
# Epoch 21/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8412 - loss: 0.3653 - val_accuracy: 0.8482 - val_loss: 0.3604
# Epoch 22/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8417 - loss: 0.3656 - val_accuracy: 0.8505 - val_loss: 0.3576
# Epoch 23/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8473 - loss: 0.3550 - val_accuracy: 0.8503 - val_loss: 0.3555
# Epoch 24/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8469 - loss: 0.3573 - val_accuracy: 0.8528 - val_loss: 0.3544
# Epoch 25/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8465 - loss: 0.3567 - val_accuracy: 0.8525 - val_loss: 0.3514
# Epoch 26/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8472 - loss: 0.3527 - val_accuracy: 0.8525 - val_loss: 0.3500
# Epoch 27/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8501 - loss: 0.3486 - val_accuracy: 0.8540 - val_loss: 0.3478
# Epoch 28/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8477 - loss: 0.3495 - val_accuracy: 0.8515 - val_loss: 0.3470
# Epoch 29/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8481 - loss: 0.3457 - val_accuracy: 0.8543 - val_loss: 0.3445
# Epoch 30/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8494 - loss: 0.3435 - val_accuracy: 0.8540 - val_loss: 0.3433
# Epoch 31/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8495 - loss: 0.3445 - val_accuracy: 0.8537 - val_loss: 0.3440
# Epoch 32/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8537 - loss: 0.3350 - val_accuracy: 0.8537 - val_loss: 0.3416
# Epoch 33/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8521 - loss: 0.3406 - val_accuracy: 0.8545 - val_loss: 0.3390
# Epoch 34/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8505 - loss: 0.3383 - val_accuracy: 0.8558 - val_loss: 0.3374
# Epoch 35/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8540 - loss: 0.3343 - val_accuracy: 0.8545 - val_loss: 0.3354
# Epoch 36/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8551 - loss: 0.3309 - val_accuracy: 0.8547 - val_loss: 0.3345
# Epoch 37/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8529 - loss: 0.3332 - val_accuracy: 0.8570 - val_loss: 0.3331
# Epoch 38/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8520 - loss: 0.3321 - val_accuracy: 0.8568 - val_loss: 0.3318
# Epoch 39/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8584 - loss: 0.3247 - val_accuracy: 0.8560 - val_loss: 0.3307
# Epoch 40/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8573 - loss: 0.3306 - val_accuracy: 0.8583 - val_loss: 0.3292
# Epoch 41/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8536 - loss: 0.3291 - val_accuracy: 0.8572 - val_loss: 0.3282
# Epoch 42/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8555 - loss: 0.3239 - val_accuracy: 0.8560 - val_loss: 0.3283
# Epoch 43/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8511 - loss: 0.3281 - val_accuracy: 0.8593 - val_loss: 0.3258
# Epoch 44/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8595 - loss: 0.3153 - val_accuracy: 0.8605 - val_loss: 0.3248
# Epoch 45/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8566 - loss: 0.3224 - val_accuracy: 0.8583 - val_loss: 0.3242
# Epoch 46/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8621 - loss: 0.3134 - val_accuracy: 0.8597 - val_loss: 0.3229
# Epoch 47/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8587 - loss: 0.3171 - val_accuracy: 0.8587 - val_loss: 0.3224
# Epoch 48/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8590 - loss: 0.3132 - val_accuracy: 0.8610 - val_loss: 0.3205
# Epoch 49/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8626 - loss: 0.3088 - val_accuracy: 0.8610 - val_loss: 0.3205
# Epoch 50/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8617 - loss: 0.3068 - val_accuracy: 0.8600 - val_loss: 0.3189
# Epoch 51/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8677 - loss: 0.3046 - val_accuracy: 0.8610 - val_loss: 0.3183
# Epoch 52/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8626 - loss: 0.3094 - val_accuracy: 0.8622 - val_loss: 0.3161
# Epoch 53/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8621 - loss: 0.3048 - val_accuracy: 0.8635 - val_loss: 0.3156
# Epoch 54/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8668 - loss: 0.3028 - val_accuracy: 0.8635 - val_loss: 0.3148
# Epoch 55/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8672 - loss: 0.3013 - val_accuracy: 0.8643 - val_loss: 0.3168
# Epoch 56/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8646 - loss: 0.3014 - val_accuracy: 0.8635 - val_loss: 0.3137
# Epoch 57/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8685 - loss: 0.2946 - val_accuracy: 0.8622 - val_loss: 0.3130
# Epoch 58/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8693 - loss: 0.2957 - val_accuracy: 0.8683 - val_loss: 0.3129
# Epoch 59/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8660 - loss: 0.3012 - val_accuracy: 0.8675 - val_loss: 0.3113
# Epoch 60/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8663 - loss: 0.2981 - val_accuracy: 0.8673 - val_loss: 0.3129
# Epoch 61/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8719 - loss: 0.2895 - val_accuracy: 0.8665 - val_loss: 0.3103
# Epoch 62/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8674 - loss: 0.2951 - val_accuracy: 0.8673 - val_loss: 0.3100
# Epoch 63/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8716 - loss: 0.2936 - val_accuracy: 0.8673 - val_loss: 0.3105
# Epoch 64/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8698 - loss: 0.2948 - val_accuracy: 0.8683 - val_loss: 0.3084
# Epoch 65/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8745 - loss: 0.2859 - val_accuracy: 0.8668 - val_loss: 0.3077
# Epoch 66/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8754 - loss: 0.2822 - val_accuracy: 0.8695 - val_loss: 0.3069
# Epoch 67/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8742 - loss: 0.2882 - val_accuracy: 0.8690 - val_loss: 0.3066
# Epoch 68/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8722 - loss: 0.2889 - val_accuracy: 0.8677 - val_loss: 0.3065
# Epoch 69/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8713 - loss: 0.2865 - val_accuracy: 0.8690 - val_loss: 0.3057
# Epoch 70/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8760 - loss: 0.2817 - val_accuracy: 0.8695 - val_loss: 0.3051
# Epoch 71/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8750 - loss: 0.2824 - val_accuracy: 0.8687 - val_loss: 0.3049
# Epoch 72/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8748 - loss: 0.2854 - val_accuracy: 0.8687 - val_loss: 0.3048
# Epoch 73/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8750 - loss: 0.2820 - val_accuracy: 0.8705 - val_loss: 0.3038
# Epoch 74/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8751 - loss: 0.2845 - val_accuracy: 0.8700 - val_loss: 0.3037
# Epoch 75/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8757 - loss: 0.2810 - val_accuracy: 0.8715 - val_loss: 0.3034
# Epoch 76/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8795 - loss: 0.2769 - val_accuracy: 0.8740 - val_loss: 0.3025
# Epoch 77/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8791 - loss: 0.2796 - val_accuracy: 0.8692 - val_loss: 0.3046
# Epoch 78/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8733 - loss: 0.2850 - val_accuracy: 0.8715 - val_loss: 0.3049
# Epoch 79/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8806 - loss: 0.2751 - val_accuracy: 0.8717 - val_loss: 0.3027
# Epoch 80/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8795 - loss: 0.2776 - val_accuracy: 0.8733 - val_loss: 0.3021
# Epoch 81/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8816 - loss: 0.2740 - val_accuracy: 0.8710 - val_loss: 0.3018
# Epoch 82/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8825 - loss: 0.2764 - val_accuracy: 0.8737 - val_loss: 0.3015
# Epoch 83/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8820 - loss: 0.2705 - val_accuracy: 0.8723 - val_loss: 0.3011
# Epoch 84/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8867 - loss: 0.2690 - val_accuracy: 0.8748 - val_loss: 0.3005
# Epoch 85/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8818 - loss: 0.2737 - val_accuracy: 0.8733 - val_loss: 0.3004
# Epoch 86/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8843 - loss: 0.2710 - val_accuracy: 0.8755 - val_loss: 0.2999
# Epoch 87/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8849 - loss: 0.2739 - val_accuracy: 0.8737 - val_loss: 0.3007
# Epoch 88/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.8792 - loss: 0.2751 - val_accuracy: 0.8737 - val_loss: 0.2999
# Epoch 89/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8835 - loss: 0.2703 - val_accuracy: 0.8740 - val_loss: 0.2998
# Epoch 90/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8854 - loss: 0.2681 - val_accuracy: 0.8733 - val_loss: 0.2996
# Epoch 91/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8830 - loss: 0.2719 - val_accuracy: 0.8740 - val_loss: 0.2994
# Epoch 92/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8854 - loss: 0.2710 - val_accuracy: 0.8760 - val_loss: 0.2988
# Epoch 93/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8859 - loss: 0.2636 - val_accuracy: 0.8758 - val_loss: 0.2984
# Epoch 94/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8845 - loss: 0.2699 - val_accuracy: 0.8752 - val_loss: 0.2984
# Epoch 95/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8868 - loss: 0.2660 - val_accuracy: 0.8763 - val_loss: 0.2979
# Epoch 96/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8838 - loss: 0.2696 - val_accuracy: 0.8775 - val_loss: 0.2984
# Epoch 97/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8845 - loss: 0.2649 - val_accuracy: 0.8770 - val_loss: 0.2983
# Epoch 98/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8840 - loss: 0.2685 - val_accuracy: 0.8698 - val_loss: 0.3034
# Epoch 99/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8839 - loss: 0.2687 - val_accuracy: 0.8733 - val_loss: 0.3019
# Epoch 100/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8858 - loss: 0.2640 - val_accuracy: 0.8692 - val_loss: 0.3011
# Epoch 101/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8862 - loss: 0.2703 - val_accuracy: 0.8788 - val_loss: 0.2972
# Epoch 102/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8863 - loss: 0.2615 - val_accuracy: 0.8692 - val_loss: 0.3005
# Epoch 103/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8909 - loss: 0.2604 - val_accuracy: 0.8770 - val_loss: 0.2974
# Epoch 104/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.8862 - loss: 0.2668 - val_accuracy: 0.8773 - val_loss: 0.2967
# Epoch 105/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8888 - loss: 0.2623 - val_accuracy: 0.8767 - val_loss: 0.2983
# Epoch 106/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.8906 - loss: 0.2582 - val_accuracy: 0.8752 - val_loss: 0.2983
# Epoch 107/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.8880 - loss: 0.2627 - val_accuracy: 0.8767 - val_loss: 0.2966
# Epoch 108/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8905 - loss: 0.2582 - val_accuracy: 0.8770 - val_loss: 0.2970
# Epoch 109/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.8906 - loss: 0.2556 - val_accuracy: 0.8777 - val_loss: 0.2973
# Epoch 110/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.8900 - loss: 0.2583 - val_accuracy: 0.8777 - val_loss: 0.2961
# Epoch 111/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8891 - loss: 0.2578 - val_accuracy: 0.8755 - val_loss: 0.2961
# Epoch 112/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8921 - loss: 0.2525 - val_accuracy: 0.8752 - val_loss: 0.2971
# Epoch 113/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8897 - loss: 0.2573 - val_accuracy: 0.8758 - val_loss: 0.2963
# Epoch 114/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8916 - loss: 0.2553 - val_accuracy: 0.8780 - val_loss: 0.2954
# Epoch 115/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.8926 - loss: 0.2561 - val_accuracy: 0.8750 - val_loss: 0.2979
# Epoch 116/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.8952 - loss: 0.2525 - val_accuracy: 0.8750 - val_loss: 0.2947
# Epoch 117/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8919 - loss: 0.2559 - val_accuracy: 0.8767 - val_loss: 0.2966
# Epoch 118/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8873 - loss: 0.2592 - val_accuracy: 0.8763 - val_loss: 0.2951
# Epoch 119/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8922 - loss: 0.2551 - val_accuracy: 0.8785 - val_loss: 0.2956
# Epoch 120/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8900 - loss: 0.2570 - val_accuracy: 0.8758 - val_loss: 0.2960
# Epoch 121/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8863 - loss: 0.2608 - val_accuracy: 0.8773 - val_loss: 0.2949
# Epoch 122/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8934 - loss: 0.2534 - val_accuracy: 0.8780 - val_loss: 0.2958
# Epoch 123/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8916 - loss: 0.2581 - val_accuracy: 0.8785 - val_loss: 0.2957
# Epoch 124/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8927 - loss: 0.2489 - val_accuracy: 0.8783 - val_loss: 0.2954
# Epoch 125/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8912 - loss: 0.2509 - val_accuracy: 0.8770 - val_loss: 0.2955
# Epoch 126/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8952 - loss: 0.2507 - val_accuracy: 0.8792 - val_loss: 0.2945
# Epoch 127/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8922 - loss: 0.2553 - val_accuracy: 0.8763 - val_loss: 0.2964
# Epoch 128/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8932 - loss: 0.2565 - val_accuracy: 0.8717 - val_loss: 0.2978
# Epoch 129/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.8957 - loss: 0.2471 - val_accuracy: 0.8783 - val_loss: 0.2947
# Epoch 130/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.8938 - loss: 0.2515 - val_accuracy: 0.8790 - val_loss: 0.2948
# Epoch 131/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8922 - loss: 0.2541 - val_accuracy: 0.8783 - val_loss: 0.2976
# Epoch 132/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8893 - loss: 0.2556 - val_accuracy: 0.8780 - val_loss: 0.2945
# Epoch 133/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.8925 - loss: 0.2521 - val_accuracy: 0.8775 - val_loss: 0.2952
# Epoch 134/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8948 - loss: 0.2511 - val_accuracy: 0.8785 - val_loss: 0.2938
# Epoch 135/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.8933 - loss: 0.2569 - val_accuracy: 0.8775 - val_loss: 0.2955
# Epoch 136/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8940 - loss: 0.2497 - val_accuracy: 0.8780 - val_loss: 0.2942
# Epoch 137/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.8943 - loss: 0.2483 - val_accuracy: 0.8775 - val_loss: 0.2950
# Epoch 138/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8979 - loss: 0.2476 - val_accuracy: 0.8805 - val_loss: 0.2948
# Epoch 139/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8972 - loss: 0.2475 - val_accuracy: 0.8773 - val_loss: 0.2948
# Epoch 140/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8973 - loss: 0.2493 - val_accuracy: 0.8785 - val_loss: 0.2936
# Epoch 141/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8986 - loss: 0.2464 - val_accuracy: 0.8780 - val_loss: 0.2938
# Epoch 142/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8980 - loss: 0.2432 - val_accuracy: 0.8765 - val_loss: 0.2996
# Epoch 143/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8944 - loss: 0.2520 - val_accuracy: 0.8783 - val_loss: 0.2939
# Epoch 144/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.8959 - loss: 0.2469 - val_accuracy: 0.8802 - val_loss: 0.2944
# Epoch 145/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8981 - loss: 0.2434 - val_accuracy: 0.8798 - val_loss: 0.2938
# Epoch 146/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9007 - loss: 0.2436 - val_accuracy: 0.8780 - val_loss: 0.2936
# Epoch 147/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9011 - loss: 0.2396 - val_accuracy: 0.8780 - val_loss: 0.2935
# Epoch 148/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8950 - loss: 0.2439 - val_accuracy: 0.8780 - val_loss: 0.2934
# Epoch 149/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8986 - loss: 0.2401 - val_accuracy: 0.8767 - val_loss: 0.2944
# Epoch 150/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9015 - loss: 0.2375 - val_accuracy: 0.8800 - val_loss: 0.2947
# Epoch 151/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8989 - loss: 0.2392 - val_accuracy: 0.8790 - val_loss: 0.2934
# Epoch 152/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8984 - loss: 0.2409 - val_accuracy: 0.8783 - val_loss: 0.2932
# Epoch 153/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8988 - loss: 0.2397 - val_accuracy: 0.8790 - val_loss: 0.2934
# Epoch 154/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8999 - loss: 0.2403 - val_accuracy: 0.8785 - val_loss: 0.2929
# Epoch 155/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9000 - loss: 0.2449 - val_accuracy: 0.8817 - val_loss: 0.2947
# Epoch 156/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8949 - loss: 0.2499 - val_accuracy: 0.8795 - val_loss: 0.2930
# Epoch 157/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9015 - loss: 0.2410 - val_accuracy: 0.8792 - val_loss: 0.2932
# Epoch 158/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9012 - loss: 0.2390 - val_accuracy: 0.8808 - val_loss: 0.2939
# Epoch 159/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8978 - loss: 0.2420 - val_accuracy: 0.8810 - val_loss: 0.2935
# Epoch 160/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8982 - loss: 0.2409 - val_accuracy: 0.8820 - val_loss: 0.2933
# Epoch 161/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8998 - loss: 0.2379 - val_accuracy: 0.8788 - val_loss: 0.2932
# Epoch 162/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.9000 - loss: 0.2369 - val_accuracy: 0.8748 - val_loss: 0.2982
# Epoch 163/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8990 - loss: 0.2443 - val_accuracy: 0.8790 - val_loss: 0.2982
# Epoch 164/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8970 - loss: 0.2467 - val_accuracy: 0.8792 - val_loss: 0.2933
# Epoch 165/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8984 - loss: 0.2345 - val_accuracy: 0.8802 - val_loss: 0.2931
# Epoch 166/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8953 - loss: 0.2457 - val_accuracy: 0.8805 - val_loss: 0.2928
# Epoch 167/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9008 - loss: 0.2385 - val_accuracy: 0.8790 - val_loss: 0.2945
# Epoch 168/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8975 - loss: 0.2440 - val_accuracy: 0.8780 - val_loss: 0.2929
# Epoch 169/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9009 - loss: 0.2406 - val_accuracy: 0.8810 - val_loss: 0.2941
# Epoch 170/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9026 - loss: 0.2379 - val_accuracy: 0.8773 - val_loss: 0.2935
# Epoch 171/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8972 - loss: 0.2448 - val_accuracy: 0.8795 - val_loss: 0.2927
# Epoch 172/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.9018 - loss: 0.2387 - val_accuracy: 0.8792 - val_loss: 0.2941
# Epoch 173/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9020 - loss: 0.2395 - val_accuracy: 0.8798 - val_loss: 0.2924
# Epoch 174/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9020 - loss: 0.2361 - val_accuracy: 0.8815 - val_loss: 0.2934
# Epoch 175/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9016 - loss: 0.2376 - val_accuracy: 0.8790 - val_loss: 0.2924
# Epoch 176/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9015 - loss: 0.2357 - val_accuracy: 0.8783 - val_loss: 0.2941
# Epoch 177/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9011 - loss: 0.2386 - val_accuracy: 0.8805 - val_loss: 0.2929
# Epoch 178/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9042 - loss: 0.2340 - val_accuracy: 0.8810 - val_loss: 0.2935
# Epoch 179/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8997 - loss: 0.2341 - val_accuracy: 0.8810 - val_loss: 0.2931
# Epoch 180/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9021 - loss: 0.2415 - val_accuracy: 0.8810 - val_loss: 0.2933
# Epoch 181/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8983 - loss: 0.2415 - val_accuracy: 0.8798 - val_loss: 0.2931
# Epoch 182/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.9029 - loss: 0.2350 - val_accuracy: 0.8785 - val_loss: 0.2949
# Epoch 183/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.9011 - loss: 0.2319 - val_accuracy: 0.8790 - val_loss: 0.2931
# Epoch 184/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9051 - loss: 0.2285 - val_accuracy: 0.8805 - val_loss: 0.2932
# Epoch 185/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9040 - loss: 0.2317 - val_accuracy: 0.8790 - val_loss: 0.2932
# Epoch 186/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8994 - loss: 0.2359 - val_accuracy: 0.8785 - val_loss: 0.2947
# Epoch 187/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9069 - loss: 0.2303 - val_accuracy: 0.8795 - val_loss: 0.2927
# Epoch 188/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8997 - loss: 0.2347 - val_accuracy: 0.8817 - val_loss: 0.2959
# Epoch 189/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9004 - loss: 0.2353 - val_accuracy: 0.8800 - val_loss: 0.2926
# Epoch 190/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9013 - loss: 0.2355 - val_accuracy: 0.8802 - val_loss: 0.2926
# Epoch 191/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9029 - loss: 0.2319 - val_accuracy: 0.8792 - val_loss: 0.2931
# Epoch 192/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.9055 - loss: 0.2285 - val_accuracy: 0.8788 - val_loss: 0.2935
# Epoch 193/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9040 - loss: 0.2336 - val_accuracy: 0.8820 - val_loss: 0.2928
# Epoch 194/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9007 - loss: 0.2331 - val_accuracy: 0.8808 - val_loss: 0.2928
# Epoch 195/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9040 - loss: 0.2343 - val_accuracy: 0.8790 - val_loss: 0.2937
# Epoch 196/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9010 - loss: 0.2372 - val_accuracy: 0.8815 - val_loss: 0.2926
# Epoch 197/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9044 - loss: 0.2337 - val_accuracy: 0.8798 - val_loss: 0.2946
# Epoch 198/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9076 - loss: 0.2309 - val_accuracy: 0.8798 - val_loss: 0.2942
# Epoch 199/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9041 - loss: 0.2339 - val_accuracy: 0.8777 - val_loss: 0.2962
# Epoch 200/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.9019 - loss: 0.2329 - val_accuracy: 0.8810 - val_loss: 0.2933

# %% [markdown]
# ## Evaluate and analyze the final results
#
# Once the training is finished it is time to analyze our final results.
# During the training the fitting function has given us some information about the training and validation losses.
# Let us begin by plotting both curves (training and validation) as a function of the number of epochs.
#
# In TensorFlow this information is provided in the `history` object which is the output of the `fit` method of the model.

# %%
# Plot both the loss and the accuracy
plt.title("Training loss")
training = history.history["loss"]
validation= history.history[f"val_loss"]
xepoch = np.arange(1, len(training)+1)
plt.plot(xepoch, training, label="Training")
plt.plot(xepoch, validation, label="Validation")
plt.xlabel("epoch")
plt.ylabel("Binary Cross Entropy")
plt.legend();

# Let's use a log scale since the improvement in the first few epochs is always faster!
plt.xscale("log")

# %% [markdown]
# ### Analyizing the results using the test data
#
# At the beginning of the notebook we separated the input data into a training and test sets. We are now going to recover the test set to evaluate the accuracy of the model.
#
# \begin{equation}
#     \text{accuracy} = 100 \frac{\text{correct}}{\text{total}}
# \end{equation}
#
# Our model returns a probability for the input to truly be a top jet so we are going to plot a few curves.
# We will start with a curve of the accuracy as a function of the threshold at which the events get catgorized as signal or background.
#
# And then we will plot what are usually known as ROC [1] curves which are the True Positive Rate and False Positive Rate.
#
# The true positive rate is often also called "signal efficiency" and it's defined as:
# \begin{equation}
#     \text{TPR} = \frac{\text{TP}}{\text{TP + FN}}
# \end{equation}
#
# While the rate of false positives is instead called background rejection:
# \begin{equation}
#     \text{FPR} = \frac{\text{FP}}{\text{FP + TN}}
# \end{equation}
#
# [1] receiver operating characteristic

# %%
def compute_accuracy(predictions_probability, labels, threshold=0.5):
    """Compute the accuracy of our model as:
        accuracy = correct / total * 100
    Where an event is selected as tagged if the probability given by the model is above threshold
    """
    predictions = np.where(predictions_probability >= threshold, 1, 0)[:, 0]
    correct = predictions == labels
    return 100 * np.count_nonzero(correct) / len(predictions)


def compute_roc(predictions_probability, labels, threshold=0.5):
    """Compute all quantities necessary for the roc curves
    returns, in this order:
        true_pos, true_neg, false_pos, false_neg
    """
    predictions = np.where(predictions_probability >= threshold, 1, 0)[:, 0]
    correct = predictions == labels
    positive = predictions == 1
    negative = predictions == 0
    true_pos = np.count_nonzero(correct & positive)
    true_neg = np.count_nonzero(correct & negative)
    false_pos = np.count_nonzero(positive) - true_pos
    false_neg = np.count_nonzero(negative) - true_neg
    return true_pos, false_pos, true_neg, false_neg


def true_positive_rate(predictions_probability, labels, threshold=0.5):
    """Compute the True Positive Rate"""
    tp, _, _, fn = compute_roc(predictions_probability, labels, threshold=threshold)
    return tp / (tp + fn)


def false_positive_rate(predictions_probability, labels, threshold=0.5):
    """Compute the False Positive Rate"""
    _, fp, tn, _ = compute_roc(predictions_probability, labels, threshold=threshold)
    return fp / (fp + tn)

def compute_auc(fpr, tpr):
    """Compute the area under the curve using the trapezoidal rule"""
    return np.trapz(tpr, fpr)

# %%
# Let's load the absolute best weights (the last saved as we set the ModelCheckpoint to save_best_only=True)
# cnn_model.load_weights("output_jets/output_path_epoch_174.weights.h5") ## uncomment and change to your best epoch

# %%
training_predictions = cnn_model.predict(in_data)
test_predictions = cnn_model.predict(test_data)
plt.rcParams["figure.figsize"] = (10, 5)

thresholds = 1 - np.arange(0, 1, 0.0003)
training_acc = [compute_accuracy(training_predictions, labels, threshold=th) for th in thresholds]
test_acc = [compute_accuracy(test_predictions, test_labels, threshold=th) for th in thresholds]

plt.title("Accuracy of the model")
plt.plot(thresholds, training_acc, label="Training accuracy")
plt.plot(thresholds, test_acc, label="Test accuracy")
plt.xlabel("Threshold")
plt.ylabel("Accuracy (%)")
plt.legend()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
test_tpr = np.array([true_positive_rate(test_predictions, test_labels, threshold=th) for th in thresholds])
test_fpr = np.array([false_positive_rate(test_predictions, test_labels, threshold=th) for th in thresholds])

# reference line for random guessing
tpr_ref = np.linspace(0,1,1000)
fpr_ref = np.linspace(0,1,1000)
auc_cnn = compute_auc(test_fpr, test_tpr)

epsilon = 1e-5
plt.title("ROC curves")
plt.plot(test_fpr, test_tpr, lw=2, label="CNN (AUC = %0.3f)" % auc_cnn)
plt.plot(fpr_ref, tpr_ref, color="grey", lw=1, linestyle="--", label="Random")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.xlim([0.0, 1.0])
plt.legend()
plt.show()

# %%
epsilon = 1e-5
plt.title("ROC curves")
plt.plot(test_tpr, 1/(test_fpr+epsilon), lw=2, label="CNN (AUC = %0.3f)" % auc_cnn)
plt.plot(tpr_ref, 1/(fpr_ref+epsilon), color="grey", lw=1, linestyle="--", label="Random")
plt.xlabel("Signal Efficiency (True Positive Rate)")
plt.ylabel("Rejection (1/False Positive Rate)")
plt.xlim([0.0, 1.0])
plt.yscale('log')
plt.legend()
plt.show()
